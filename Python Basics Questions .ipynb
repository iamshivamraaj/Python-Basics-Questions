# %% [markdown]
# #functions

# %% [markdown]
# 1. What is Python, and why is it popular?
#
#  - Python is a high-level, versatile programming language known for its simple syntax and readability. It's popular because it's easy to learn, supports multiple programming paradigms, has extensive libraries and frameworks, and is widely used in areas like web development, data science, and AI.

# %% [markdown]
# 2. What is an interpreter in Python?
#    - A Python interpreter is a program that executes Python code line by line, translating it into machine-readable instructions for direct execution. In short, the Python interpreter acts as a bridge between human-readable Python code and machine-executable instructions.

# %% [markdown]
# 3. What are pre-defined keywords in Python?
#   - Pre-defined keywords in Python are reserved words that have specific meanings and purposes in the Python programming language. They cannot be used as variable names, function names, or identifiers.

# %% [markdown]
# 4. Can keywords be used as variable names?
#   - No, keywords cannot be used as variable names in Python. Keywords are reserved words with specific meanings and functions in the Python language, and using them as variable names would cause a syntax error.

# %% [markdown]
# 5. What is mutability in Python?
#   - Mutability in Python refers to an object’s ability to change its state or contents after it has been created.
#
# Mutable Objects: Can be modified after creation (e.g., lists, dictionaries, sets).
# Immutable Objects: Cannot be modified after creation (e.g., strings, tuples, integers).

# %% [markdown]
# 6. Why are lists mutable, but tuples are immutable?
#   - Lists are mutable because they are designed for flexibility. They are intended to hold collections of data that may need to change over time (e.g., adding, removing, or modifying elements). This allows for efficient updates and dynamic changes to the data.
#
#   - Tuples are immutable because they are designed for fixed collections of data. Once created, the data in a tuple cannot be modified. This provides benefits like data integrity, performance optimization, and the ability to use tuples as keys in dictionaries and elements in sets (since they are hashable). The immutability ensures that the data remains constant and safe from accidental changes.

# %% [markdown]
# 7.  What is the difference between “==” and “is” operators in Python?
#   - The difference between the == and is operators in Python is:
#
#   - == (Equality Operator): Compares the values of two objects to check if they are equal. It checks whether the contents of the objects are the same, regardless of whether they are stored in the same location in memory.
#
#   - is (Identity Operator): Compares the identities of two objects to check if they are the same object in memory. It checks whether both variables refer to the exact same object in memory, not just objects with the same value.

# %% [markdown]
# 8. What are logical operators in Python?
#   - Logical operators in Python are used to combine conditional statements and return Boolean results (True or False). They allow you to perform logical operations on expressions.

# %% [markdown]
# 9. What is type casting in Python?
#   - Type casting in Python refers to the process of converting a variable from one data type to another. Python provides functions to explicitly cast or convert one type to another. This is useful when you need to perform operations on data that requires a specific type.

# %% [markdown]
# 10. What is the difference between implicit and explicit type casting?
#   - Implicit Type Casting:
# Implicit type casting, also known as automatic type conversion, is when the Python interpreter automatically converts one data type into another without requiring explicit instructions from the programmer. It usually happens when performing operations between different data types where one type can be safely converted into another.
#
#   - Explicit Type Casting:
# Explicit type casting, also known as manual type conversion, is when the programmer explicitly converts one data type into another using built-in Python functions such as int(), float(), str(), or bool(). This is done when the programmer wants precise control over the type conversion process.

# %% [markdown]
# 11. What is the purpose of conditional statements in Python?
#   - Conditional statements in Python are used to control the flow of a program based on certain conditions. They allow the program to make decisions and execute specific blocks of code only when certain conditions are met.

# %% [markdown]
# 12. How does the elif statement work?
#   - The elif (short for "else if") statement is used to check multiple conditions sequentially after an initial if condition fails. It allows you to test multiple expressions and execute the block of code associated with the first condition that evaluates to True.

# %% [markdown]
# 13. What is the difference between for and while loops?
#   - for Loop:
# A for loop is used to iterate over a sequence (e.g., list, tuple, string, or range) and execute a block of code for each item in that sequence. It is primarily used when the number of iterations is known in advance.
#
#   - while Loop:
# A while loop is used to execute a block of code repeatedly as long as a given condition evaluates to True. It is primarily used when the number of iterations is unknown and depends on a condition being met

# %% [markdown]
# 14. Describe a scenario where a while loop is more suitable than a for loop.
#   - Scenario Where a while Loop is More Suitable Than a for Loop
# Scenario: User Login System with Limited Attempts
#
# Imagine you're building a user login system where the user has 3 attempts to enter the correct password. You don't know in advance how many attempts the user will need (it could be 1, 2, or 3), so a while loop is more appropriate because it depends on a condition rather than a fixed number of iterations.

# %% [markdown]
# **Practical** **Questions**

# %% [markdown]
# 1. Write a Python program to print "Hello, World!"

# %%
print("hello,world")
# Out:
# hello,world

# %% [markdown]
# 2. Write a Python program that displays your name and age.

# %%
name = "shivam"
age = 22
print("Name:", name)
print("Age:", age)
# Out:
# Name: shivam
# Age: 22

# %% [markdown]
# 3.  Write code to print all the pre-defined keywords in Python using the keyword library.

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# 4. Write a program that checks if a given word is a Python keyword.

# %%
import keyword

word = input("shivam raj: ")
if keyword.iskeyword(word):
    print(f"'{word}' is a Python keyword.")
else:
    print(f"'{word}' is not a Python keyword.")

# %% [markdown]
# 5. Create a list and tuple in Python, and demonstrate how attempting to change an element works differently
# for each.

# %%
# List (Mutable)
my_list = [1, 2, 3]
my_list[0] = 100
print("List after modification:", my_list)

# Tuple (Immutable)
my_tuple = (1, 2, 3)
# my_tuple[0] = 100  # This will raise an error
print("Tuple remains unchanged:", my_tuple)

# %% [markdown]
# 6. 0 Write a function to demonstrate the behavior of mutable and immutable arguments.

# %%
def mutable_example(my_list):
    my_list.append(4)
    print("Inside function (mutable):", my_list)

def immutable_example(my_tuple):
    my_tuple = my_tuple + (4,)
    print("Inside function (immutable):", my_tuple)

mutable_example([1, 2, 3])
immutable_example((1, 2, 3))

# %% [markdown]
# 7. Write a function to demonstrate the behavior of mutable and immutable arguments.

# %%
a = True
b = False
print("a and b:", a and b)
print("a or b:", a or b)
print("not a:", not a)

# %% [markdown]
# 8. Write a program to demonstrate the use of logical operators.

# %%
user_input = input("Enter a number: ")
int_input = int(user_input)
float_input = float(user_input)
bool_input = bool(user_input)
print("Integer:", int_input, "Float:", float_input, "Boolean:", bool_input)

# %% [markdown]
# 9. Write a Python program to convert user input from string to integer, float, and boolean types.

# %%
my_list = ['1', '2', '3']
int_list = [int(x) for x in my_list]
print("Integer list:", int_list)

# %% [markdown]
# 10. Write code to demonstrate type casting with list elements.

# %%
num = float(input("Enter a number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

# %% [markdown]
# 11. Write a program that checks if a number is positive, negative, or zero.

# %%
for i in range(1, 11):
    print(i)

# %% [markdown]
# 12. Write a for loop to print numbers from 1 to 10.

# %% [markdown]
# 13. Write a Python program to find the sum of all even numbers between 1 and 50.

# %%
even_sum = sum(i for i in range(1, 51) if i % 2 == 0)
print("Sum of even numbers:", even_sum)

# %% [markdown]
# 14.  Write a program to reverse a string using a while loop.

# %%
string = input("Enter a string: ")
reversed_string = ""
index = len(string) - 1

while index >= 0:
    reversed_string += string[index]
    index -= 1

print("Reversed string:", reversed_string)
